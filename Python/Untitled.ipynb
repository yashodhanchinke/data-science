# %%
set1 = {1,2,3,(8,5)}
print(set1)
type(set1)
set1.add(7)
set1
# Out:
# {1, 2, 3, (8, 5)}
# {(8, 5), 1, 2, 3, 7}

# %%
set2 = {"str","str","fhg","kel"}
type(set2)
print(set2)
# Out:
# {'fhg', 'str', 'kel'}

# %%
l1 = [1,2,3,4,[1,2]]
l1
# Out:
# [1, 2, 3, 4, [1, 2]]

# %%
tup = (1,2,3,(2,3))
tup
# Out:
# (1, 2, 3, (2, 3))

# %%
h1 = {"dict":"hello","he":1,{"kl":"deff"},"hel":"hell"}
h1
# Out:
#   Cell In[32], line 1
#     h1 = {"dict":"hello","he":1,{"kl":"deff"},"hel":"hell"}
#                                             ^
# SyntaxError: ':' expected after dictionary key

# %%
1) can we add in set
2) types of for loops
3) how initialize empty set             
4) how initialize empty dict
5) empty tuple
6) dict in pytho what are rules

# %%
# Out:
# tuple
